# %% [markdown]
# # PatchCore Failure Analysis
# Loads generated evidence only; it does not recalibrate thresholds.

# %%
from pathlib import Path

metrics = sorted(Path("../artifacts/experiments").glob("*/metrics.json"))
metrics
