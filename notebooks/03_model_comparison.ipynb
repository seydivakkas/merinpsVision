# %% [markdown]
# # Model Comparison
# Comparison is valid only for the same verified manifest, split, preprocessing, and metric contract.

# %%
from weavevision.models.registry import ModelRegistry
from weavevision.settings import load_settings

settings = load_settings()
ModelRegistry(settings.resolved_artifacts_root() / "models").list()
