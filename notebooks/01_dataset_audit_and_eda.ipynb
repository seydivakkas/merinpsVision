# %% [markdown]
# # Dataset Audit and EDA
# Uses only public `weavevision` APIs. Generated output is not benchmark evidence.

# %%
from pathlib import Path

from weavevision.data.manifest import read_manifest

manifest_path = Path("../data/manifests/weavevision_fixture.json")
manifest = read_manifest(manifest_path) if manifest_path.exists() else None
manifest
